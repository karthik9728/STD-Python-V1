# %%
# 1️⃣ Built-in Modules – import and import as
import math   # normal import

print(math.pi)
print(math.sqrt(16))
print(math.ceil(4.2))
print(math.floor(4.8))
# Out:
# 3.141592653589793
# 4.0
# 5
# 4

# %%
# import with alias
import math as m

print(m.pi)
print(m.sqrt(81))
# Out:
# 3.141592653589793
# 9.0

# %%
# 2️⃣ from module import function

from math import sqrt, pi

print(pi)
print(sqrt(49))
# Out:
# 3.141592653589793
# 7.0

# %%
from math import *

print(sin(0))
print(cos(0))
print(factorial(5))
# Out:
# 0.0
# 1.0
# 120

# %%
# 3️⃣ random Module
import random

# random int between 1 and 10
print(random.randint(1, 10))

# random float between 0 and 1
print(random.random())

# random choice from list
colors = ["red", "green", "blue", "yellow"]
print(random.choice(colors))

# shuffle list
random.shuffle(colors)
print(colors)
# Out:
# 6
# 0.9350457828070907
# yellow
# ['blue', 'red', 'yellow', 'green']

# %%
# 4️⃣ datetime Module
import datetime

current_datetime = datetime.datetime.now()
print("Current DateTime:", current_datetime)

print("Year:", current_datetime.year)
print("Month:", current_datetime.month)
print("Day:", current_datetime.day)
# Out:
# Current DateTime: 2025-12-04 13:15:47.732251
# Year: 2025
# Month: 12
# Day: 4

# %%
from datetime import date, timedelta

today = date.today()
print("Today:", today)

tomorrow = today + timedelta(days=1)
print("Tomorrow:", tomorrow)
# Out:
# Today: 2025-12-04
# Tomorrow: 2025-12-05

# %%
# Package from 3rd party packages
# pip install colorama
from colorama import init
from colorama import Fore
from colorama import Style

print(Fore.RED,"See am red color!!!")
print(Fore.GREEN,"See am switched to green color now!!!")
print(Style.RESET_ALL)
print('welcome to python course')
# Out:
#  See am red color!!!
#  See am switched to green color now!!!
#
# welcome to python course
