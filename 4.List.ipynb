# %%
# 🟦 LIST (list)

# A list is an ordered, changeable (mutable) collection that allows duplicate items.

# %%
fruits = ["apple", "banana", "orange"]
numbers = [10, 20, 30, 40]
mixed = [10, "hello", True, 99.5]

print(fruits)
print(numbers)
print(mixed)
# Out:
# ['apple', 'banana', 'orange']
# [10, 20, 30, 40]
# [10, 'hello', True, 99.5]

# %%
# 🔹 Accessing Items
print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[-1])
print(fruits[-2])
print(fruits[-3])
# print(fruits[-4]) Error: List index out of range
# Out:
# apple
# banana
# orange
# orange
# banana
# apple

# %%
# 🔹 List is Mutable
fruits[1] = "grapes"
print(fruits)
# Out:
# ['apple', 'grapes', 'orange']

# %%
# 🔹 Adding & Removing Items
# add at end
fruits.append("kiwi")     
print(fruits)
# add at index
fruits.insert(1, "watermelon")   
print(fruits)
# remove specific value
fruits.remove("apple")     
print(fruits)
# remove last item
fruits.pop()               
print(fruits)
# remove based on index
fruits.pop(1)               
print(fruits)
fruits.insert(1,"grapes")
print(fruits)
# Out:
# ['apple', 'grapes', 'orange', 'kiwi']
# ['apple', 'watermelon', 'grapes', 'orange', 'kiwi']
# ['watermelon', 'grapes', 'orange', 'kiwi']
# ['watermelon', 'grapes', 'orange']
# ['watermelon', 'orange']
# ['watermelon', 'grapes', 'orange']

# %%
# 🔹 Sorting & Reversing
fruits.sort()
print(fruits)
fruits.reverse()
print(fruits)

numbers.sort()
print(numbers)
numbers.reverse()
print(numbers)
# Out:
# ['grapes', 'orange', 'watermelon']
# ['watermelon', 'orange', 'grapes']
# [10, 20, 30, 40]
# [40, 30, 20, 10]

# %%
# 🔹 Find Length
print(f'The length of fruits list: {len(fruits)}')
print(f'The length of numbers list: {len(numbers)}')
print(f'The length of mixed list: {len(mixed)}')
# Out:
# The length of fruits list: 3
# The length of numbers list: 4
# The length of mixed list: 4

# %%
# 🔹 Slicing
print(fruits)
print(fruits[1:])
print(fruits[::-1])
print(numbers)
print(numbers[::-1])
print(numbers[1:4:2])   # slice with step
# Out:
# ['watermelon', 'orange', 'grapes']
# ['orange', 'grapes']
# ['grapes', 'orange', 'watermelon']
# [40, 30, 20, 10]
# [10, 20, 30, 40]
# [30, 10]

# %%
# list concatenation
shopping_list_one=["bread","milk","cheese"]
shopping_list_two=["playstation","xbox","iphone"]
shopping_list = shopping_list_one + shopping_list_two
print(shopping_list)
# Out:
# ['bread', 'milk', 'cheese', 'playstation', 'xbox', 'iphone']
