# %%
name="Swetha"
age=25
height= 175.45

# %%
print(name)
# Out:
# Swetha

# %%
print("Name:",name)
print("Age:",age)
print("Height:",height)
# Out:
# Name: Swetha
# Age: 25
# Height: 175.45

# %%
# Varibale name cannot start with number
5name="Raji"
# Out:
#   Cell In[10], line 2
#     5name="Raji"
#     ^
# SyntaxError: invalid decimal literal

# %%
# No Space between variable name
first name = "Roshan"
# Out:
#   Cell In[11], line 2
#     first name = "Roshan"
#           ^
# SyntaxError: invalid syntax

# %%
# Can't use special character : "",<>()?/@#$%^&*-+~
first-name="Roshan"
# Out:
#   Cell In[12], line 2
#     first-name="Roshan"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# 🧾 What is PEP 8?
    # PEP = Python Enhancement Proposal
    # PEP 8 = The official Python style guide

# It tells Python developers how to write clean and readable code, including rules for:
    # Naming conventions
    # Indentation
    # Spacing
    # Line length
    # Imports
    # Comments
    # Structure of functions and classes

# 📘 Example from PEP 8:
    # variable_name → snake_case
    # function_name → snake_case
    # class names → PascalCase
    # constants → ALL_CAPS

# %%
# ✔ snake_case is standard in
# Python (PEP8 recommended)

first_name="Roshan"
print(first_name);
# Out:
# Roshan

# %%
# ✔ camelCase is common in
# Java
# JavaScript
# C#
# Dart
# Kotlin

lastName="Kumar"
print(lastName)
# Out:
# Kumar

# %%
# Don't use reserved keywords example: list , str
list="Rajesh"

# %%
# Python uses Dynamic Typing
x = 10
print(x)
# Out:
# 10

# %%
x="Hello"
print(x)
# Out:
# Hello

# %%
x=3.14
print(x)
# Out:
# 3.14

# %%
# re-using the value by using variable name
userName="Harini"
emailAddress="harini97@gmail.com"
phoneNo=9876543210

# %%
print("Username:",userName,"\nEmail:", emailAddress, "\nContact:",phoneNo)
# Out:
# Username: Harini
# Email: harini97@gmail.com
# Contact: 9876543210

# %%
# Check the datatype

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(height)
# Out:
# float

# %%
print(type(name), type(age), type(height))
# Out:
# <class 'str'> <class 'int'> <class 'float'>
