# %%
import platform

os_type = platform.system()

print("You are using:", os_type)
# Out:
# You are using: Windows

# %%
pwd
# Out:
# 'D:\\Github\\STD-Python-V1'

# %%
import os

os.getcwd()
# Out:
# 'D:\\Github\\STD-Python-V1'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '1.Variables_and_DataTypes.ipynb',
#  '10.Loop.ipynb',
#  '11.Functions_and_Methods.ipynb',
#  '12.Input_and_Output.ipynb',
#  '13.Mini_Project.ipynb',
#  '14.OOP.ipynb',
#  '15.Exception_Handling.ipynb',
#  '16.File_Handling.ipynb',
#  '17.Modules_Packages.ipynb',
#  '18.Project.ipynb',
#  '19.Generators.ipynb',
#  '2.String.ipynb',
#  '20.Collection_Features.ipynb',
#  '21.OS.ipynb',
#  '22.Regular_Expressions.ipynb',
#  '23.Decorator.ipynb',
#  '24.Time.ipynb',
#  '25.Advanced_Function_Concepts.ipynb',
#  '26.Multithreading.ipynb',
#  '27.Multiprocessing.ipynb',
#  '27.Multiprocessing.py',
#  '3.Boolean.ipynb',
#  '4.List.ipynb',
#  '5.Tuple.ipynb',
#  '6.Set.ipynb',
#  '7.Dictionary.ipynb',
#  '8.Operators.ipynb',
#  '9.Conditional_Statements.ipynb',
#  'example.txt',
#  'my_modules',
#  'notes.txt',
#  'posts.txt',
#  'README.md',
#  'student_notes.txt']

# %%
os.listdir('D:\\Github')
# Out:
# ['Linux', 'STD-Python-V1']

# %%
if not os.path.exists('Source_Folder'):
    os.mkdir('Source_Folder')

# %%
if not os.path.exists('Destination_Folder'):
    os.mkdir('Destination_Folder')

# %%
f = open('Source_Folder/Notes.txt','w')
f.write('Hello viewers!!!')
f.close()

# %%
import shutil

shutil.move('Source_Folder/Notes.txt','Destination_Folder')
# Out:
# 'Destination_Folder\\Notes.txt'

# %%
os.listdir('D:\\Github\\STD-Python-V1\\Destination_Folder')
# Out:
# ['Notes.txt']

# %%
# Delete File
os.unlink('D:\\Github\\STD-Python-V1\\Destination_Folder\\Notes.txt')

# %%
os.listdir('D:\\Github\\STD-Python-V1\\Destination_Folder')
# Out:
# []

# %%
# Dlete Folder
if os.path.exists('Source_Folder'):
    os.rmdir('Source_Folder')
if os.path.exists('Destination_Folder'):
    os.rmdir('Destination_Folder')
